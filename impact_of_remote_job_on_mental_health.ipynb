# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rj = pd.read_csv("Impact_of_Remote_Work_on_Mental_Health.csv")
rj
# Out:
#      Employee_ID  Age      Gender           Job_Role    Industry  \
# 0        EMP0001   32  Non-binary                 HR  Healthcare
# 1        EMP0002   40      Female     Data Scientist          IT
# 2        EMP0003   59  Non-binary  Software Engineer   Education
# 3        EMP0004   27        Male  Software Engineer     Finance
# 4        EMP0005   49        Male              Sales  Consulting
# ...          ...  ...         ...                ...         ...
# 4995     EMP4996   32        Male              Sales  Consulting
# 4996     EMP4997   39      Female              Sales  Healthcare
# 4997     EMP4998   42      Female              Sales  Healthcare
# 4998     EMP4999   27      Female              Sales  Healthcare
# 4999     EMP5000   29        Male                 HR          IT
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                      13        Hybrid                     47
# ...

# %%
print(rj.head())
# Out:
#   Employee_ID  Age      Gender           Job_Role    Industry  \
# 0     EMP0001   32  Non-binary                 HR  Healthcare
# 1     EMP0002   40      Female     Data Scientist          IT
# 2     EMP0003   59  Non-binary  Software Engineer   Education
# 3     EMP0004   27        Male  Software Engineer     Finance
# 4     EMP0005   49        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
# ...

# %%
print(rj.describe())
# Out:
#                Age  Years_of_Experience  Hours_Worked_Per_Week  \
# count  5000.000000          5000.000000            5000.000000
# mean     40.995000            17.810200              39.614600
# std      11.296021            10.020412              11.860194
# min      22.000000             1.000000              20.000000
# 25%      31.000000             9.000000              29.000000
# 50%      41.000000            18.000000              40.000000
# 75%      51.000000            26.000000              50.000000
# max      60.000000            35.000000              60.000000
#
#        Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# count                 5000.000000               5000.000000
# mean                     7.559000                  2.984200
# std                      4.636121                  1.410513
# min                      0.000000                  1.000000
# 25%                      4.000000                  2.000000
# ...

# %%
#check for duplicates
print(rj.duplicated().sum())
# Out:
# 0

# %%
# Check for missing values
print(rj.isnull().sum())
# Out:
# Employee_ID                             0
# Age                                     0
# Gender                                  0
# Job_Role                                0
# Industry                                0
# Years_of_Experience                     0
# Work_Location                           0
# Hours_Worked_Per_Week                   0
# Number_of_Virtual_Meetings              0
# Work_Life_Balance_Rating                0
# Stress_Level                            0
# Mental_Health_Condition              1196
# Access_to_Mental_Health_Resources       0
# Productivity_Change                     0
# Social_Isolation_Rating                 0
# Satisfaction_with_Remote_Work           0
# Company_Support_for_Remote_Work         0
# Physical_Activity                    1629
# Sleep_Quality                           0
# Region                                  0
# dtype: int64

# %%
#In the Income column replace null values with Mode value 
rj["Mental_Health_Condition"].mode()
# Out:
# 0    Burnout
# Name: Mental_Health_Condition, dtype: object

# %%
#Fill the null values with the Mode value
rj["Menta_Health_Condition"] = rj["Mental_Health_Condition"].fillna("Mental_Health_Condition, ")

# %%
#In the Income column replace null values with Mode value 
rj["Physical_Activity"].mode()
# Out:
# 0    Weekly
# Name: Physical_Activity, dtype: object

# %%
#Fill the null values with the Mode value
rj["Physical_Activity"] = rj["Physical_Activity"].fillna("Mental_Health_Condition, ")

# %% [markdown]
# ## AGE DISTRIBUTION

# %%
plt.figure(figsize=(8, 5))
sns.histplot(rj['Age'], bins=10, kde=True, color='navy')
plt.title("Distribution of Employee Age", fontsize=14)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x='Gender', data=rj, palette='Blues')
plt.title("Gender Distribution", fontsize=14)
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_2224\4287021328.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=rj, palette='Blues')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Job_Role', data=rj, order=rj['Job_Role'].value_counts().index, palette='coolwarm')
plt.title("Job Role Distribution", fontsize=14)
plt.xlabel("Count")
plt.ylabel("Job Role")
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_2224\1448375769.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Job_Role', data=rj, order=rj['Job_Role'].value_counts().index, palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
rj['Industry'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('Set2'))
plt.title("Industry Distribution", fontsize=14)
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Years_of_Experience', data=rj, color='teal')
plt.title("Years of Experience Distribution", fontsize=14)
plt.xlabel("Years of Experience")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Work_Location', data=rj, order=rj['Work_Location'].value_counts().index, palette='viridis')
plt.title("Work Location Distribution", fontsize=14)
plt.xlabel("Count")
plt.ylabel("Work Location")
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_2224\3127855473.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Work_Location', data=rj, order=rj['Work_Location'].value_counts().index, palette='viridis')

# %%
plt.figure(figsize=(8, 5))
sns.histplot(rj['Hours_Worked_Per_Week'], bins=10, kde=True, color='purple')
plt.title("Hours Worked Per Week", fontsize=14)
plt.xlabel("Hours Worked")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(rj['Number_of_Virtual_Meetings'], bins=10, kde=True, color='darkorange')
plt.title("Number of Virtual Meetings", fontsize=14)
plt.xlabel("Virtual Meetings")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Work_Life_Balance_Rating', data=rj, color='gold')
plt.title("Work-Life Balance Rating", fontsize=14)
plt.xlabel("Work-Life Balance Rating")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(x='Stress_Level', data=rj, color='coral')
plt.title("Stress Level Distribution", fontsize=14)
plt.xlabel("Stress Level")
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x='Mental_Health_Condition', data=rj, palette='coolwarm')
plt.title("Mental Health Condition Distribution", fontsize=14)
plt.xlabel("Mental Health Condition")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_2224\983585008.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Mental_Health_Condition', data=rj, palette='coolwarm')

# %%
plt.figure(figsize=(6, 5))
rj['Access_to_Mental_Health_Resources'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('Paired'))
plt.title("Access to Mental Health Resources", fontsize=14)
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(rj['Productivity_Change'], kde=True, color='seagreen')
plt.title("Productivity Change", fontsize=14)
plt.xlabel("Productivity Change")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(rj['Satisfaction_with_Remote_Work'], kde=True, color='forestgreen')
plt.title("Satisfaction with Remote Work", fontsize=14)
plt.xlabel("Satisfaction Rating")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(rj['Sleep_Quality'], kde=True, color='dodgerblue')
plt.title("Sleep Quality Distribution", fontsize=14)
plt.xlabel("Sleep Quality Rating")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Work_Life_Balance_Rating', y='Job_Role', data=rj, palette='Set3')
plt.title("Work-Life Balance Rating across Job Roles", fontsize=14)
plt.xlabel("Work-Life Balance Rating")
plt.ylabel("Job Role")
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_2224\3376024637.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Work_Life_Balance_Rating', y='Job_Role', data=rj, palette='Set3')

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x='Gender', hue='Mental_Health_Condition', data=rj, palette='coolwarm')
plt.title("Gender vs Mental Health Condition", fontsize=14)
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x='Number_of_Virtual_Meetings', y='Productivity_Change', data=rj, marker='o', color='royalblue')
plt.title("Number of Virtual Meetings vs Productivity Change", fontsize=14)
plt.xlabel("Number of Virtual Meetings")
plt.ylabel("Productivity Change")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='Mental_Health_Condition', y='Physical_Activity', data=rj, palette='muted')
plt.title("Physical Activity to Mental Health Condition", fontsize=14)
plt.xlabel("Mental Health Condition")
plt.ylabel("Physical Activity")
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_2224\4128286581.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Mental_Health_Condition', y='Physical_Activity', data=rj, palette='muted')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Job_Role', hue='Access_to_Mental_Health_Resources', data=rj, palette='Set2')
plt.title("Access to Mental Health Resources across Job Roles", fontsize=14)
plt.xlabel("Job Role")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Work_Life_Balance_Rating', y='Hours_Worked_Per_Week', data=rj, palette='Spectral')
plt.title("Hours Worked Per Week vs Work-Life Balance Rating", fontsize=14)
plt.xlabel("Work-Life Balance Rating")
plt.ylabel("Hours Worked Per Week")
plt.show()
# Out:
# C:\Users\miracle\AppData\Local\Temp\ipykernel_2224\3510109945.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Work_Life_Balance_Rating', y='Hours_Worked_Per_Week', data=rj, palette='Spectral')

# %% [markdown]
# ##  Hypothesis Testing
# *Test whether there is a significant difference in Mental Health Score between different Job Types.*

# %%
from scipy.stats import f_oneway
from sklearn.preprocessing import LabelEncoder

# Convert 'Mental_Health_Condition' from string labels to numeric labels
le = LabelEncoder()
rj['Mental_Health_Condition_Encoded'] = le.fit_transform(rj['Mental_Health_Condition'])

# Perform ANOVA using the encoded mental health condition
job_groups = [rj[rj['Job_Role'] == group]['Mental_Health_Condition_Encoded'] for group in rj['Job_Role'].unique()]
stat, p_value = f_oneway(*job_groups)

# Print results
print(f'ANOVA test p-value: {p_value}')
# Out:
# ANOVA test p-value: 0.012501648713003728

# %% [markdown]
# ## p-value = 0.0125
# ## This means that there is about a 1.25% chance that the differences in mental health conditions across the ## job roles occurred by random chance.
# ## Since 0.0125 < 0.05, we reject the null hypothesis.
